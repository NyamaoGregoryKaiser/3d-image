# %% [markdown]
# <a href="https://colab.research.google.com/github/NyamaoGregoryKaiser/3d-image/blob/main/Heatmap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/cosym/Downloads/facts mon.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-aeda61277628> in <cell line: 1>()
# ----> 1 data = pd.read_csv('C:/Users/cosym/Downloads/facts mon.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
data = pd.read_csv(r'C:/Users/cosym/Downloads/facts mon.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d56b80cbc6f4> in <cell line: 1>()
# ----> 1 data = pd.read_csv(r'C:/Users/cosym/Downloads/facts mon.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Check if the file exists in the current directory
import os

file_path = "facts mon.csv"
if not os.path.isfile(file_path):
    # If the file is not found, check a different directory
    file_path = "../Downloads/facts mon.csv"

# Read the CSV file
data = pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e044fad29205> in <cell line: 10>()
#       8
#       9 # Read the CSV file
# ---> 10 data = pd.read_csv(file_path)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os

current_working_directory = os.getcwd()

print(f"Current working directory: {current_working_directory}")
# Out:
# Current working directory: /content

# %%
import os

# Change the current working directory to the directory containing your CSV file
os.chdir('C:\Users\cosym\Downloads')

# Read the CSV file
data = pd.read_csv("facts mon.csv")

# %%
data = pd.read_csv('facts mon.csv')

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.heatmap(data, cmap='coolwarm')  # You can choose different color maps
plt.title('Heatmap of Your Data')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.show()

# %%
data = pd.read_csv('data3.csv')

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.heatmap(data, cmap='PiYG')  # You can choose different color maps
plt.title('Heatmap of Factssales')
plt.xlabel('Billing Id')
plt.ylabel('Amount ')
plt.show()

# %%
data = pd.read_csv('data4.csv')

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
sns.heatmap(data, cmap='PiYG')  # You can choose different color maps
plt.title('Heatmap of Factssales')
plt.xlabel('Billing Id')
plt.ylabel('Amount ')
plt.show()

# %%
import numpy as np

# Load data from CSV file into a NumPy array
data_array = np.loadtxt('data3.csv', delimiter=',', skiprows=1)  # Assuming the first row contains headers

# Alternatively, you can use genfromtxt for handling missing values
# data_array = np.genfromtxt('your_data.csv', delimiter=',', skip_header=1)

print(data_array)
# Out:
# [[1.40000000e+01 6.51118641e+06 2.00000000e+00 6.52796629e+06
#   3.00000000e+00]
#  [1.20000000e+01 4.73056036e+06 5.00000000e+00 4.76940263e+06
#   1.20000000e+01]
#  [2.80000000e+01 9.27640830e+05 4.00000000e+00 9.39138540e+05
#   1.70000000e+01]
#  ...
#  [3.23000000e+02 7.85622692e+06 3.00000000e+00 7.94235462e+06
#   5.29000000e+02]
#  [1.68000000e+02 2.39985137e+06 1.00000000e+00 2.43331507e+06
#   5.31000000e+02]
#  [1.45000000e+02 7.60281191e+06 2.00000000e+00 7.68957286e+06
#   5.38000000e+02]]
